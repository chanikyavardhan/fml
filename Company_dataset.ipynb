# %% [markdown]
# <a href="https://colab.research.google.com/github/chanikyavardhan/fml/blob/main/Company_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# Import all necessary libraries.

# %%
data=pd.read_csv("Company_data.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# The head methd is used to display first five rows in the data set.

# %%
X = data.drop('Sales', axis=1).values
y = data['Sales'].values

# %% [markdown]
# Now X contains the data except label data part and Y contains the labeled data part.

# %% [markdown]
# As it is a Simple LinearRegression it use only one input data so we consider the tv data as our input data

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %% [markdown]
# By using the correlation method we get the majority values.
# From the above tabular data Tv plays a major sales rater than others.

# %%
x_tv = X[:, 0]

# %% [markdown]
# To get the datatype of x_tv and y we use type function.

# %%
type(x_tv),type(y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
x_tv.shape,y.shape
# Out:
# ((200,), (200,))

# %% [markdown]
# Now plot the graph for x_tv and y(label part)

# %%
plt.scatter(x_tv, y)
plt.xlabel('Number of TV advertisements')
plt.ylabel('Value of sales')
plt.show()

# %% [markdown]
# Reshape the x_tv and y using reshape().

# %%
x_tv = x_tv.reshape(-1,1)
y = y.reshape(-1, 1)

# %% [markdown]
# Now print the reshaped x_tv and y.

# %%
x_tv.shape,y.shape
# Out:
# ((200, 1), (200, 1))

# %% [markdown]
# Now split the data into training data and testing data in that 20% of data comes under training data and remaining 80% of data comes under the training data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_tv, y, test_size=0.2, random_state=42)

# %% [markdown]
# After spliting of data find the shapes of train data and test data

# %%
X_train.shape,X_test.shape
# Out:
# ((160, 1), (40, 1))

# %% [markdown]
# Now fit the LinearRegression model

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred1 = reg.predict(X_train)
print(f'Performance of the model on training data :\n')
print(f'MAE = {mean_absolute_error(y_train, y_pred1)}')
print(f'MSE = {mean_squared_error(y_train, y_pred1)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_train, y_pred1))}')
print(f'R_2 = {r2_score(y_train, y_pred1)}')
# Out:
# Performance of the model on training data :
#
# MAE = 1.8005092256620792
# MSE = 4.998442356450173
# RMSE = 2.235719650683013
# R_2 = 0.8134866044709264

# %% [markdown]
# Now pass the X_train into the model so it display the y_predict values and find the errors.

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred2 = reg.predict(X_test)
print(f'Performance of the model on test data :\n')
print(f'MAE = {mean_absolute_error(y_test, y_pred2)}')
print(f'MSE = {mean_squared_error(y_test, y_pred2)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_test, y_pred2))}')
print(f'R_2 = {r2_score(y_test, y_pred2)}')
# Out:
# Performance of the model on test data :
#
# MAE = 1.9502948931650088
# MSE = 6.101072906773963
# RMSE = 2.470035001123256
# R_2 = 0.802561303423698

# %% [markdown]
# **CONCLUSION** we can say that the testing data is best fit for the linear regression model

# %% [markdown]
# ![image.png](data:image/png;base64,...)
